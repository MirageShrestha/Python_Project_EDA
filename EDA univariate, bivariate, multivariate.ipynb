# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('supermarket_sales - Sheet1.csv', parse_dates=['Date'])
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
cat=[]
num=[]
for column in df.columns:
    if df[column].nunique() > 10:
        num.append(column)
    else:
        cat.append(column)

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %% [markdown]
# UNIVARIATE ANALYSIS

# %% [markdown]
# 1. Find Aggregate Sales Among Branches (Categorical Column)

# %%
df['Branch'].value_counts().plot(kind='pie', autopct=lambda p: '{:.2f}%'.format(p), startangle=90, counterclock=False)
plt.ylabel('')  # Optional: to remove the y-label
plt.title('Branch Distribution')
plt.show()

# %%
ax=sns.countplot(x=df.Branch)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# 2. Find the most popular payment method used by customers

# %%
ax=df['Payment'].value_counts().plot(kind='bar')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax=sns.countplot(x=df.Payment)
for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# 3. Find the distribution of customer ratings (Numerical Column)

# %%
df.Rating.skew()
# Out:
# 0.00900964876573073

# %%
sns.distplot(df.Rating)
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %% [markdown]
# 4. Find the Distribution of cost of good sold (Numerical Column)

# %%
sns.distplot(df.cogs)
# Out:
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
df.cogs.skew()
# Out:
# 0.8925698049581418

# %%
sns.boxplot(x=df.cogs)
# Out:
# <Axes: xlabel='cogs'>

# %% [markdown]
# BIVARIATE AND MULTIVARIATE

# %% [markdown]
# 1. Does the cogs affects the ratigs that the customers provide? (numerical - numerical)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
sns.scatterplot(x=df['cogs'], y=df['Rating'])
# Out:
# <Axes: xlabel='cogs', ylabel='Rating'>

# %% [markdown]
# 2. Does Gross income affect the ratings that the customers provide? (numerical - numerical)

# %%
sns.scatterplot(x=df['gross income'], y=df.Rating)
# Out:
# <Axes: xlabel='gross income', ylabel='Rating'>

# %% [markdown]
# 3. Most profitablle branch as per gross income. (Numerical - categorical)

# %%
sns.barplot(x=df.Branch, y=df['gross income'])
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %% [markdown]
# 4. Is there any relationsjip Between Gender and Gross Income? (NUm - Cat)

# %%
sns.barplot(x=df.Branch, y=df['gross income'], hue=df.City)
# Out:
# <Axes: xlabel='Branch', ylabel='gross income'>

# %%
sns.barplot(x=df.Gender, y=df['gross income'])
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(x=df.Gender, y=df['gross income'])
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %%
sns.boxplot(x=df.Gender, y=df['gross income'], hue=df['Customer type'])
# Out:
# <Axes: xlabel='Gender', ylabel='gross income'>

# %% [markdown]
# 5. Find the product line that generates the most income. (num - cat)

# %%
sns.barplot(x=df['Product line'], y=df['gross income'])
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# 6. Highest unit price in product line (Num - Cat)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
ax=sns.barplot(x=df['Product line'], y=df['Unit price'])
for bars in ax.containers:
    ax.bar_label(bars)
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# 7. Different payment methods used by customers citywise (cat - cat)

# %%
pd.crosstab(df.Payment, df.City)
# Out:
# City         Mandalay  Naypyitaw  Yangon
# Payment
# Cash              110        124     110
# Credit card       109         98     104
# Ewallet           113        106     126

# %%
sns.heatmap(pd.crosstab(df.City, df.Payment))
# Out:
# <Axes: xlabel='Payment', ylabel='City'>

# %% [markdown]
# 8. Product line purchased in highest quantity

# %%
sns.barplot(x=df['Product line'], y=df.Quantity)
plt.xticks(rotation = 60)
plt.show()

# %% [markdown]
# 9. Display daily sales by day of the week

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
dw_mapping={
    0:'Mon',
    1:'Tue',
    2:'Wed',
    3:'Thu',
    4:'Fri',
    5:'Sat',
    6:'Sun'
}

# %%
df['day_of_week']=df.Date.dt.dayofweek.map(dw_mapping)

# %%
df['day_of_week'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='day_of_week'>

# %% [markdown]
# 10. What will be the highest months for sales

# %%
month_mapping={
    1:'Jan',
    2:'Feb',
    3:'Mar',
    4:'Apr',
    5:'May',
    6:'Jun',
    7:'Jul',
    8:'Aug',
    9:'Sep',
    10:'Oct',
    11:'Nov',
    12:'Dec',
}

# %%
df['Month']=df.Date.dt.month.map(month_mapping)

# %%
df['Month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Month'>
