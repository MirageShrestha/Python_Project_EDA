# %%
import pandas as pd
import numpy as np

# %%
dict={
    'Name': ['Mirage', 'Samagya', 'Parbat', 'Ashaya','Nishab', 'Rachel', 'Prekshya'],
    'Marks': [98, np.nan, 85, 92, 88, np.nan, 93],
    'Gender': ['Male','Female', 'Male', 'Male', 'Male','Female', 'Female'],
    'email':['mirageshrestha7@gmail.com', 'samagyapradhan7@yahoo.com', 'parbatbasnet123@gmail.com', 'ashayasah@gmail.com', 'nishabghatani@gmail.com', 'rachelstha@gmail.com','pandaprekshya@hotmail.com']
}

df = pd.DataFrame(dict)
df
# Out:
#        Name  Marks  Gender                      email
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com
# 1   Samagya    NaN  Female  samagyapradhan7@yahoo.com
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com
# 3    Ashaya   92.0    Male        ashayasah@gmail.com
# 4    Nishab   88.0    Male    nishabghatani@gmail.com
# 5    Rachel    NaN  Female       rachelstha@gmail.com
# 6  Prekshya   93.0  Female  pandaprekshya@hotmail.com

# %%
df.head(3)
# Out:
#       Name  Marks  Gender                      email
# 0   Mirage   98.0    Male  mirageshrestha7@gmail.com
# 1  Samagya    NaN  Female  samagyapradhan7@gmail.com
# 2   Parbat   85.0    Male  parbatbasnet123@gmail.com

# %%
df.tail(3)
# Out:
#        Name  Marks  Gender                    email
# 4    Nishab   88.0    Male  nishabghatani@gmail.com
# 5    Rachel    NaN  Female     rachelstha@gmail.com
# 6  Prekshya   93.0  Female  pandaprekshya@gmail.com

# %%
df.head(-2)
# Out:
#       Name  Marks  Gender                      email
# 0   Mirage   98.0    Male  mirageshrestha7@gmail.com
# 1  Samagya    NaN  Female  samagyapradhan7@gmail.com
# 2   Parbat   85.0    Male  parbatbasnet123@gmail.com
# 3   Ashaya   92.0    Male        ashayasah@gmail.com
# 4   Nishab   88.0    Male    nishabghatani@gmail.com

# %%
df.tail(-3)
# Out:
#        Name  Marks  Gender                    email
# 3    Ashaya   92.0    Male      ashayasah@gmail.com
# 4    Nishab   88.0    Male  nishabghatani@gmail.com
# 5    Rachel    NaN  Female     rachelstha@gmail.com
# 6  Prekshya   93.0  Female  pandaprekshya@gmail.com

# %%
df.shape
# Out:
# (7, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    7 non-null      object
#  1   Marks   5 non-null      float64
#  2   Gender  7 non-null      object
#  3   email   7 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 352.0+ bytes

# %%
df.isnull()
# Out:
#     Name  Marks  Gender  email
# 0  False  False   False  False
# 1  False   True   False  False
# 2  False  False   False  False
# 3  False  False   False  False
# 4  False  False   False  False
# 5  False   True   False  False
# 6  False  False   False  False

# %%
df.describe()
# Out:
#            Marks
# count   5.000000
# mean   91.200000
# std     4.969909
# min    85.000000
# 25%    88.000000
# 50%    92.000000
# 75%    93.000000
# max    98.000000

# %%
df.Gender.unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df.Gender.nunique()
# Out:
# 2

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      4
# Female    3
# Name: count, dtype: int64

# %%
df
# Out:
#        Name  Marks  Gender                      email
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com
# 1   Samagya    NaN  Female  samagyapradhan7@gmail.com
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com
# 3    Ashaya   92.0    Male        ashayasah@gmail.com
# 4    Nishab   88.0    Male    nishabghatani@gmail.com
# 5    Rachel    NaN  Female       rachelstha@gmail.com
# 6  Prekshya   93.0  Female    pandaprekshya@gmail.com

# %%
df.fillna(0)
# Out:
#        Name  Marks  Gender                      email
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com
# 1   Samagya    0.0  Female  samagyapradhan7@gmail.com
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com
# 3    Ashaya   92.0    Male        ashayasah@gmail.com
# 4    Nishab   88.0    Male    nishabghatani@gmail.com
# 5    Rachel    0.0  Female       rachelstha@gmail.com
# 6  Prekshya   93.0  Female    pandaprekshya@gmail.com

# %%
df.fillna(method='ffill')
# Out:
#        Name  Marks  Gender                      email
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com
# 1   Samagya   98.0  Female  samagyapradhan7@gmail.com
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com
# 3    Ashaya   92.0    Male        ashayasah@gmail.com
# 4    Nishab   88.0    Male    nishabghatani@gmail.com
# 5    Rachel   88.0  Female       rachelstha@gmail.com
# 6  Prekshya   93.0  Female    pandaprekshya@gmail.com

# %%
df
# Out:
#        Name  Marks  Gender                      email
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com
# 1   Samagya    NaN  Female  samagyapradhan7@gmail.com
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com
# 3    Ashaya   92.0    Male        ashayasah@gmail.com
# 4    Nishab   88.0    Male    nishabghatani@gmail.com
# 5    Rachel    NaN  Female       rachelstha@gmail.com
# 6  Prekshya   93.0  Female    pandaprekshya@gmail.com

# %%
df.Marks.fillna(df['Marks'].mean(),inplace=True)

# %%
df
# Out:
#        Name  Marks  Gender                      email
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com
# 1   Samagya   91.2  Female  samagyapradhan7@gmail.com
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com
# 3    Ashaya   92.0    Male        ashayasah@gmail.com
# 4    Nishab   88.0    Male    nishabghatani@gmail.com
# 5    Rachel   91.2  Female       rachelstha@gmail.com
# 6  Prekshya   93.0  Female    pandaprekshya@gmail.com

# %%
df[(df.Marks>80) & (df.Marks<90)]
# Out:
#      Name  Marks Gender                      email
# 2  Parbat   85.0   Male  parbatbasnet123@gmail.com
# 4  Nishab   88.0   Male    nishabghatani@gmail.com

# %%
df[df.Marks.between(80,90)]
# Out:
#      Name  Marks Gender                      email
# 2  Parbat   85.0   Male  parbatbasnet123@gmail.com
# 4  Nishab   88.0   Male    nishabghatani@gmail.com

# %%
df.sort_values(by='Marks', ascending = False)
# Out:
#        Name  Marks  Gender                      email
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com
# 6  Prekshya   93.0  Female    pandaprekshya@gmail.com
# 3    Ashaya   92.0    Male        ashayasah@gmail.com
# 1   Samagya   91.2  Female  samagyapradhan7@gmail.com
# 5    Rachel   91.2  Female       rachelstha@gmail.com
# 4    Nishab   88.0    Male    nishabghatani@gmail.com
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com

# %%
df.nlargest(5,'Marks')['Name']
# Out:
# 0      Mirage
# 6    Prekshya
# 3      Ashaya
# 1     Samagya
# 5      Rachel
# Name: Name, dtype: object

# %%
df.Marks.mean()
# Out:
# 91.2

# %%
half_marks=df.Marks.apply(lambda x:x/2)
# Out:
#        Name  Marks  Gender                      email
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com
# 1   Samagya   91.2  Female  samagyapradhan7@gmail.com
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com
# 3    Ashaya   92.0    Male        ashayasah@gmail.com
# 4    Nishab   88.0    Male    nishabghatani@gmail.com
# 5    Rachel   91.2  Female       rachelstha@gmail.com
# 6  Prekshya   93.0  Female    pandaprekshya@gmail.com

# %%
def marks(x):
    return x//2
df.Marks.apply(marks)
# Out:
# 0    49.0
# 1    45.0
# 2    42.0
# 3    46.0
# 4    44.0
# 5    45.0
# 6    46.0
# Name: Marks, dtype: float64

# %%
df['Male_Female']=df.Gender.map({'Male':1, 'Female':0})
df
# Out:
#        Name  Marks  Gender                      email  Male_Female
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com            1
# 1   Samagya   91.2  Female  samagyapradhan7@gmail.com            0
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com            1
# 3    Ashaya   92.0    Male        ashayasah@gmail.com            1
# 4    Nishab   88.0    Male    nishabghatani@gmail.com            1
# 5    Rachel   91.2  Female       rachelstha@gmail.com            0
# 6  Prekshya   93.0  Female    pandaprekshya@gmail.com            0

# %%
df.drop('Male_Female', axis = 1, inplace = True)

# %%
df
# Out:
#        Name  Marks  Gender                      email
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com
# 1   Samagya   91.2  Female  samagyapradhan7@gmail.com
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com
# 3    Ashaya   92.0    Male        ashayasah@gmail.com
# 4    Nishab   88.0    Male    nishabghatani@gmail.com
# 5    Rachel   91.2  Female       rachelstha@gmail.com
# 6  Prekshya   93.0  Female    pandaprekshya@gmail.com

# %%
df.sort_values(by = 'Marks', ascending = False)
# Out:
#        Name  Marks  Gender                      email
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com
# 6  Prekshya   93.0  Female    pandaprekshya@gmail.com
# 3    Ashaya   92.0    Male        ashayasah@gmail.com
# 1   Samagya   91.2  Female  samagyapradhan7@gmail.com
# 5    Rachel   91.2  Female       rachelstha@gmail.com
# 4    Nishab   88.0    Male    nishabghatani@gmail.com
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com

# %%
df[df.Gender=='Female'][['Name','Marks']]
# Out:
#        Name  Marks
# 1   Samagya   91.2
# 5    Rachel   91.2
# 6  Prekshya   93.0

# %%
df
# Out:
#        Name  Marks  Gender                      email
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com
# 1   Samagya   91.2  Female  samagyapradhan7@gmail.com
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com
# 3    Ashaya   92.0    Male        ashayasah@gmail.com
# 4    Nishab   88.0    Male    nishabghatani@gmail.com
# 5    Rachel   91.2  Female       rachelstha@gmail.com
# 6  Prekshya   93.0  Female    pandaprekshya@gmail.com

# %%
df[df.Gender.isin(['Female'])][['Name', 'Marks']]
# Out:
#        Name  Marks
# 1   Samagya   91.2
# 5    Rachel   91.2
# 6  Prekshya   93.0

# %%
df.rename(columns={'Marks':'Final_Marks'})
# Out:
#        Name  Final_Marks  Gender                      email
# 0    Mirage         98.0    Male  mirageshrestha7@gmail.com
# 1   Samagya         91.2  Female  samagyapradhan7@gmail.com
# 2    Parbat         85.0    Male  parbatbasnet123@gmail.com
# 3    Ashaya         92.0    Male        ashayasah@gmail.com
# 4    Nishab         88.0    Male    nishabghatani@gmail.com
# 5    Rachel         91.2  Female       rachelstha@gmail.com
# 6  Prekshya         93.0  Female    pandaprekshya@gmail.com

# %%
df1=pd.DataFrame({
    'Name': ['Avishek'],
    'Marks': [97],
    'Gender': ['Male'],
    'email':['avishelshrestha7@gmail.com']
})

# %%
df2=pd.concat([df, df1], ignore_index=True)

# %%
df2
# Out:
#        Name  Marks  Gender                       email
# 0    Mirage   98.0    Male   mirageshrestha7@gmail.com
# 1   Samagya   91.2  Female   samagyapradhan7@gmail.com
# 2    Parbat   85.0    Male   parbatbasnet123@gmail.com
# 3    Ashaya   92.0    Male         ashayasah@gmail.com
# 4    Nishab   88.0    Male     nishabghatani@gmail.com
# 5    Rachel   91.2  Female        rachelstha@gmail.com
# 6  Prekshya   93.0  Female     pandaprekshya@gmail.com
# 7   Avishek   97.0    Male  avishelshrestha7@gmail.com

# %%
df2.loc[:,'Marks':'Gender']
# Out:
#    Marks  Gender
# 0   98.0    Male
# 1   91.2  Female
# 2   85.0    Male
# 3   92.0    Male
# 4   88.0    Male
# 5   91.2  Female
# 6   93.0  Female
# 7   97.0    Male

# %%
df2.iloc[0]
# Out:
# Name                         Mirage
# Marks                          98.0
# Gender                         Male
# email     mirageshrestha7@gmail.com
# Name: 0, dtype: object

# %%
df2.iloc[:,3]
# Out:
# 0     mirageshrestha7@gmail.com
# 1     samagyapradhan7@gmail.com
# 2     parbatbasnet123@gmail.com
# 3           ashayasah@gmail.com
# 4       nishabghatani@gmail.com
# 5          rachelstha@gmail.com
# 6       pandaprekshya@gmail.com
# 7    avishelshrestha7@gmail.com
# Name: email, dtype: object

# %%
df['Name_Marks']=df['Marks'].apply(str)+ ' ' +df['Name']

# %%
df1.replace('avishelshrestha7@gmail.com', 'avishekshrestha7@gmail.com')
# Out:
#       Name  Marks Gender                       email
# 0  Avishek     97   Male  avishekshrestha7@gmail.com

# %%
df
# Out:
#        Name  Marks  Gender                      email     Name_Marks
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com    98.0 Mirage
# 1   Samagya   91.2  Female  samagyapradhan7@gmail.com   91.2 Samagya
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com    85.0 Parbat
# 3    Ashaya   92.0    Male        ashayasah@gmail.com    92.0 Ashaya
# 4    Nishab   88.0    Male    nishabghatani@gmail.com    88.0 Nishab
# 5    Rachel   91.2  Female       rachelstha@gmail.com    91.2 Rachel
# 6  Prekshya   93.0  Female    pandaprekshya@gmail.com  93.0 Prekshya

# %%
df.groupby('Gender')['Marks'].mean().sort_values().to_frame()
# Out:
#         Marks
# Gender
# Male    90.75
# Female  91.80

# %%
type(df.groupby('Gender')['Marks'].mean().sort_values().to_frame())
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        Name  Marks  Gender                      email
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com
# 1   Samagya    NaN  Female  samagyapradhan7@yahoo.com
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com
# 3    Ashaya   92.0    Male        ashayasah@gmail.com
# 4    Nishab   88.0    Male    nishabghatani@gmail.com
# 5    Rachel    NaN  Female       rachelstha@gmail.com
# 6  Prekshya   93.0  Female  pandaprekshya@hotmail.com

# %%
 list=[]
for email in df['email']:
    list.append(email.split('@')[1])

# %%
list
# Out:
# ['gmail.com',
#  'yahoo.com',
#  'gmail.com',
#  'gmail.com',
#  'gmail.com',
#  'gmail.com',
#  'hotmail.com']

# %%
df['temp']=list

# %%
df
# Out:
#        Name  Marks  Gender                      email         temp
# 0    Mirage   98.0    Male  mirageshrestha7@gmail.com    gmail.com
# 1   Samagya    NaN  Female  samagyapradhan7@yahoo.com    yahoo.com
# 2    Parbat   85.0    Male  parbatbasnet123@gmail.com    gmail.com
# 3    Ashaya   92.0    Male        ashayasah@gmail.com    gmail.com
# 4    Nishab   88.0    Male    nishabghatani@gmail.com    gmail.com
# 5    Rachel    NaN  Female       rachelstha@gmail.com    gmail.com
# 6  Prekshya   93.0  Female  pandaprekshya@hotmail.com  hotmail.com

# %%
df.temp.value_counts()
# Out:
# temp
# gmail.com      5
# yahoo.com      1
# hotmail.com    1
# Name: count, dtype: int64

# %%
df.email.apply(lambda x:x.split('@')[1]).value_counts()
# Out:
# email
# gmail.com      5
# yahoo.com      1
# hotmail.com    1
# Name: count, dtype: int64
